# %%
import numpy as np
import matplotlib.pyplot as plt
import plothelpers
import utility as ut
import mesa_reader as mr

G    = 6.6743e-8    
c    = 2.99792458e10    # [cm]
Msun = 1.9891e33        # [g]
Rsun = 6.957e10         # [cm]
pc   = 3.08567758128e18 # [cm]

kpc  = 1.e3*pc          # [cm]
Mpc  = 1.e6*pc          # [cm] 
au   = 1.49598073e13    # [cm]
yr   = 31556952.        # [secs]

# %%
run1 = ut.read2BodyData('./NSData6/', './StarProfiles6/')

# %%
fig,ax = plt.subplots(facecolor='w')
ax.set(xlabel = 'X [$R_{\odot}$]', ylabel = 'Y [$R_{\odot}$]')
ax.plot(run1.x1, run1.y1, label ='Donor')
ax.plot(run1.x2, run1.y2,'--', label = 'Accretor')
ax.plot(run1.x1[0], run1.y1[0], 'o', color= 'blue')
ax.plot(run1.x2[0], run1.y2[0], 'o', color='orange')
ax.plot(run1.xs, run1.ys, label ='Seperation')
ax.legend(loc='best')
ax.grid(True)

fig,ax = plt.subplots(facecolor='w')
ax.set(xlabel ='Time [yr]', ylabel = '$R_{\odot}$')
ax.plot(run1.tl, run1.rs)
ax.grid(True)
